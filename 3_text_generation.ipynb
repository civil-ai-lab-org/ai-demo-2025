# %% [markdown]
# 自然言語処理（Text Generation）
#
# モデル例: rinna/japanese-gpt-1b (日本語対応のGPT)
#
# デモ内容:
#
#
#
# *  入力した日本語の文章を続きから生成

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
# モデルとトークナイザのロード
tokenizer = AutoTokenizer.from_pretrained("rinna/japanese-gpt-1b")
model = AutoModelForCausalLM.from_pretrained("rinna/japanese-gpt-1b")

# %% [markdown]
# 下のプロンプトを変えてみましょう！

# %%
# シンプルで具体的なプロンプト
prompt = """
犬は次のような特徴があります:
- 犬は人間の良きパートナーです。
- 犬は
"""

# %%
input_ids = tokenizer.encode(prompt, return_tensors="pt")
# attention_maskを明示的に設定
attention_mask = input_ids.new_ones(input_ids.shape)

# %%
# テキスト生成
outputs = model.generate(
    input_ids=input_ids,
    attention_mask=attention_mask,
    max_length=100,
    num_return_sequences=1,
    pad_token_id=tokenizer.eos_token_id,
    do_sample=True,
    temperature=0.7,
)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# 犬は次のような特徴があります: - 犬は人間の良きパートナーです。 - 犬は 犬の散歩コース - 犬の散歩は、犬のストレスや健康状態を改善します。 - 飼い主の
